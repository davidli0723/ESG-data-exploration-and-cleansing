# %%
import pandas as pd
import re
import os
import matplotlib.pyplot as plt

# %%
raw_data_files = os.listdir("../ingestion_service/data/raw_data")
csv_files = [f for f in raw_data_files if re.search(r'.*\.csv$', f)]
csv_files
# Out:
# ['esg_raw_data_on_corporations_myu_2.csv',
#  'esg_raw_data_on_corporations_myu_3.csv',
#  'esg_raw_data_on_corporations_7.csv',
#  'esg_raw_data_on_corporations_6.csv',
#  'esg_raw_data_on_corporations_myu_4.csv',
#  'esg_raw_data_on_corporations_myu_5.csv',
#  'esg_raw_data_on_corporations_1.csv']

# %%
dfs = []
number_of_rows = 0
for csv in csv_files:
    print(f"Reading {csv}")
    df_chunk = pd.read_csv(f"../ingestion_service/data/raw_data/{csv}", sep='|')
    print(df_chunk.shape)
    number_of_rows += df_chunk.shape[0]
    # Optional preprocessing here
    # df_chunk = df_chunk[['column1', 'column2']]  # example
    
    dfs.append(df_chunk)

print("total number of rows in raw data: ", number_of_rows)
df = pd.concat(dfs, ignore_index=True)
# Out:
# Reading esg_raw_data_on_corporations_myu_2.csv
# (1322420, 15)
# Reading esg_raw_data_on_corporations_myu_3.csv
# (1024697, 15)
# Reading esg_raw_data_on_corporations_7.csv
# (86371, 15)
# Reading esg_raw_data_on_corporations_6.csv
# (257603, 15)
# Reading esg_raw_data_on_corporations_myu_4.csv
# (812742, 15)
# Reading esg_raw_data_on_corporations_myu_5.csv
# (522838, 15)
# Reading esg_raw_data_on_corporations_1.csv
# (2764252, 15)
# total number of rows in raw data:  6790923

# %%
def add_industry_matching(esg_df):
    try:
        companies_df = pd.read_csv('../ingestion_service/data/industry.csv')

        companies_df = companies_df.rename(columns={'Industry': 'industry_name'})
        companies_df.drop(columns=['Company Name'], inplace=True)

        res_df = pd.merge(esg_df, companies_df, how="left", on=['perm_id'])
        return res_df
        
    except Exception as e:
        raise Exception(f'Exception while running industry matching {e}')

# %%
df = add_industry_matching(df)

# %%
df.head()
# Out:
#                                         company_name     perm_id data_type  \
# 0  Abdullah Saad Mohammed Abo Moati for Bookstore...  5052962521       int
# 1  Abdullah Saad Mohammed Abo Moati for Bookstore...  5052962521       int
# 2  Abdullah Saad Mohammed Abo Moati for Bookstore...  5052962521     float
# 3  Abdullah Saad Mohammed Abo Moati for Bookstore...  5052962521       int
# 4  Abdullah Saad Mohammed Abo Moati for Bookstore...  5052962521     float
#
#    disclosure                                 metric_description  \
# 0    REPORTED  Does the company have a formal grievance repor...
# 1  CALCULATED  Does the company have appropriate communicatio...
# 2   ESTIMATED  External cost of indirect emissions of polluta...
# 3    REPORTED  Does the company have appropriate communicatio...
# 4    REPORTED  The average overall attendance percentage of b...
#
#                          metric_name metric_unit  metric_value metric_year  \
# 0        GRIEVANCE_REPORTING_PROCESS      Yes/No          0.00  2022-12-31
# 1  IMPROVEMENT_TOOLS_BUSINESS_ETHICS      Yes/No          0.00  2019-12-31
# 2             AIRPOLLUTANTS_INDIRECT   USD (000)     193067.06  2021-12-31
# 3  IMPROVEMENT_TOOLS_BUSINESS_ETHICS      Yes/No          0.00  2024-12-31
# 4          BOARDMEETINGATTENDANCEAVG           %        100.00  2022-12-31
#
#    nb_points_of_observations  metric_period provider_name  \
# 0                        331            NaN    Clarity AI
# 1                        331            NaN    Clarity AI
# 2                        331            NaN    Clarity AI
# 3                        331            NaN    Clarity AI
# 4                        331            NaN    Clarity AI
#
#          reported_date pillar headquarter_country industry_name
# 0  2022-12-31 00:00:00      S        Saudi Arabia     Chemicals
# 1  2019-09-27 14:29:37      S        Saudi Arabia     Chemicals
# 2                  NaN      E        Saudi Arabia     Chemicals
# 3  2024-12-31 00:00:00      S        Saudi Arabia     Chemicals
# 4  2022-12-31 00:00:00      G        Saudi Arabia     Chemicals

# %% [markdown]
# # Rename Eurofidai Metrics name

# %%
# Filter numerical metrics
int_metric_names = df[df['data_type'] == 'int']['metric_name'].unique().tolist()
metric_list = df['metric_name'].unique().tolist()
numerical_metric = df[df['metric_unit'] != 'Yes/No']
metrics_info = numerical_metric[['metric_name', 'metric_description', 'metric_unit', 'data_type', 'pillar']].drop_duplicates()
metrics_info.sort_values(by=['pillar', 'metric_name'])
# Out:
#                             metric_name  \
# 1029               AIRPOLLUTANTS_DIRECT
# 2                AIRPOLLUTANTS_INDIRECT
# 1958        ANALYTICWASTERECYCLINGRATIO
# 54                      CO2DIRECTSCOPE1
# 20                    CO2INDIRECTSCOPE2
# 39                    CO2INDIRECTSCOPE3
# 4180543              CO2_NO_EQUIVALENTS
# 115882             ELECTRICITYPURCHASED
# 257                   EMS_CERTIFIED_PCT
# 511474            ENERGYPURCHASEDDIRECT
# 243                      ENERGYUSETOTAL
# 187                      HAZARDOUSWASTE
# 2331        NATURAL_RESOURCE_USE_DIRECT
# 36                         NOXEMISSIONS
# 11         PARTICULATE_MATTER_EMISSIONS
# 1929                RENEWENERGYCONSUMED
# 1917                RENEWENERGYPRODUCED
# 2159               RENEWENERGYPURCHASED
# 67                         SOXEMISSIONS
# 1909           TRANALYTICRENEWENERGYUSE
# 62                         VOCEMISSIONS
# 215                          WASTETOTAL
# 2005                     WASTE_RECYCLED
# 5                  WATERWITHDRAWALTOTAL
# 71                    WATER_USE_PAI_M10
# 107                ANALYTICAUDITCOMMIND
# 90                  ANALYTICBOARDFEMALE
# 134                 ANALYTICCOMPCOMMIND
# 534          ANALYTICEMPLOYMENTCREATION
# 74                   ANALYTICINDEPBOARD
# 119           ANALYTICNOMINATIONCOMMIND
# 9104     ANALYTICNONAUDITAUDITFEESRATIO
# 53                 ANALYTICNONEXECBOARD
# 19147        ANNUAL_MEDIAN_COMPENSATION
# 158             AUDITCOMMNONEXECMEMBERS
# 1046                   AVGTRAININGHOURS
# 4             BOARDMEETINGATTENDANCEAVG
# 23              CEO_ANNUAL_COMPENSATION
# 9518               CEO_PAY_RATIO_MEDIAN
# 14153         COMMMEETINGSATTENDANCEAVG
# 325              COMPCOMMNONEXECMEMBERS
# 299              ANALYTICTOTALDONATIONS
# 1897                 EMPLOYEEFATALITIES
# 7661          GENDER_PAY_GAP_PERCENTAGE
# 81           HUMAN_RIGHTS_VIOLATION_PAI
# 1912                    LOSTWORKINGDAYS
# 2012                           TIRTOTAL
# 1904                      TRADEUNIONREP
# 1976                  TURNOVEREMPLOYEES
# 1101                     WOMENEMPLOYEES
# 4152                      WOMENMANAGERS
#
#                                         metric_description  \
# 1029     External cost of pollutants released to air by...
# 2        External cost of indirect emissions of polluta...
# 1958     Total recycled and reused waste produced in to...
# 54       Scope 1 emissions that occur within a company’...
# 20       Scope 2 emissions that result from the generat...
# 39       Scope 3 emissions that occur in the value chai...
# 4180543  The estimated total CO2 emission in tons (with...
# 115882                Electricity purchased in gigajoules.
# 257      The percentage of company sites or subsidiarie...
# 511474              Direct energy purchased in gigajoules.
# 243      Total energy consumed by a company within its ...
# 187      Total amount of hazardous waste produced in tons.
# 2331     External cost of the direct extraction of mine...
# 36          Total amount of NOx emissions emitted in tons.
# 11       Amount of particulate matter (a complex mixtur...
# 1929        Total renewable energy consumed in Gigajoules.
# 1917     Total renewable energy produced for self-consu...
# 2159     Total renewable energy purchased for self-cons...
# 67          Total amount of SOx emissions emitted in tons.
# 1909     Total energy consumed from primary renewable e...
# 62       Amount of Volatile Organic Compounds (VOC) emi...
# 215                Total amount of waste produced in tons.
# 2005     Total waste that is generated by the company a...
# 5                  Total water withdrawal in cubic meters.
# 71       Average amount of water consumed and reclaimed...
# 107      Percentage of independent board members on the...
# 90                     Percentage of females on the board.
# 134      Percentage of independent board members on the...
# 534                  Employment growth over the last year.
# 74       Percentage of independent board members as rep...
# 119      Percentage of non-executive board members on t...
# 9104     All non-audit fees divided by the audit and au...
# 53              Percentage of non-executive board members.
# 19147    Median annual compensation for the entire comp...
# 158      Percentage of non-executive board members on t...
# 1046      Average hours of training per year per employee.
# 4        The average overall attendance percentage of b...
# 23       Total annual compensation for the highest paid...
# 9518     Already reported ratio of CEO compensation ove...
# 14153    The average overall attendance percentage of b...
# 325      Percentage of non-executive board members on t...
# 299      Total amount of all donations divided by net s...
# 1897     Number of employee fatalities resulting from o...
# 7661           Percentage of remuneration of women to men.
# 81       Number of identified cases of severe human rig...
# 1912     Total working days lost by the workforce (empl...
# 2012     Rate of total number of injuries (Total Injury...
# 1904     Percentage of employees represented by indepen...
# 1976                      Percentage of employee turnover.
# 1101                        Percentage of women employees.
# 4152                         Percentage of women managers.
#
#                                                metric_unit data_type pillar
# 1029                                             USD (000)     float      E
# 2                                                USD (000)     float      E
# 1958                                                     %     float      E
# 54                                               Tons CO2e     float      E
# 20                                               Tons CO2e     float      E
# 39                                               Tons CO2e     float      E
# 4180543                                           Tons CO2     float      E
# 115882                                                  GJ     float      E
# 257                                                      %     float      E
# 511474                                                  GJ     float      E
# 243                                                     GJ     float      E
# 187                                                   Tons     float      E
# 2331                                             USD (000)     float      E
# 36                                             Tons of NOx     float      E
# 11                                                    Tons     float      E
# 1929                                                    GJ     float      E
# 1917                                                    GJ     float      E
# 2159                                                    GJ     float      E
# 67                                             Tons of SOx     float      E
# 1909                                                     %     float      E
# 62                                             Tons of VOC     float      E
# 215                                                   Tons     float      E
# 2005                                                  Tons     float      E
# 5                                             Cubic meters     float      E
# 71       Cubic meters / million EUR of revenue of inves...     float      E
# 107                                                      %     float      G
# 90                                                       %     float      G
# 134                                                      %     float      G
# 534         % growth in number of employees over last year     float      G
# 74                                                       %     float      G
# 119                                                      %     float      G
# 9104                           Non / audit USD / audit USD     float      G
# 53                                                       %     float      G
# 19147                                                  USD     float      G
# 158                                                      %     float      G
# 1046                                        Hours/employee     float      G
# 4                                                        %     float      G
# 23                                                     USD     float      G
# 9518                                                 Ratio     float      G
# 14153                                                    %     float      G
# 325                                                      %     float      G
# 299                 USD donated per million of revenue USD     float      S
# 1897                                  Number of fatalities     float      S
# 7661                                                     %     float      S
# 81                                      Number of breaches       int      S
# 1912                                        Number of days     float      S
# 2012                               Injured / million hours     float      S
# 1904                                                     %     float      S
# 1976                                                     %     float      S
# 1101                                                     %     float      S
# 4152                                                     %     float      S

# %%
# export metrics to csv
metrics_info.sort_values(by=['pillar', 'metric_name']).to_csv('../ingestion_service/data/numerical_metric_info.csv', index=False)

# %%
# manual upload updated metric name
updated_metric_info = pd.read_csv('../ingestion_service/data/numerical_metric_info_update.csv')
updated_metric_info
# Out:
#                        metric_name  \
# 0             AIRPOLLUTANTS_DIRECT
# 1           AIRPOLLUTANTS_INDIRECT
# 2      ANALYTICWASTERECYCLINGRATIO
# 3                  CO2DIRECTSCOPE1
# 4                CO2INDIRECTSCOPE2
# 5                CO2INDIRECTSCOPE3
# 6               CO2_NO_EQUIVALENTS
# 7             ELECTRICITYPURCHASED
# 8                EMS_CERTIFIED_PCT
# 9            ENERGYPURCHASEDDIRECT
# 10                  ENERGYUSETOTAL
# 11                  HAZARDOUSWASTE
# 12     NATURAL_RESOURCE_USE_DIRECT
# 13                    NOXEMISSIONS
# 14    PARTICULATE_MATTER_EMISSIONS
# 15             RENEWENERGYCONSUMED
# 16             RENEWENERGYPRODUCED
# 17            RENEWENERGYPURCHASED
# 18                    SOXEMISSIONS
# 19        TRANALYTICRENEWENERGYUSE
# 20                    VOCEMISSIONS
# 21                      WASTETOTAL
# 22                  WASTE_RECYCLED
# 23            WATERWITHDRAWALTOTAL
# 24               WATER_USE_PAI_M10
# 25            ANALYTICAUDITCOMMIND
# 26             ANALYTICBOARDFEMALE
# 27             ANALYTICCOMPCOMMIND
# 28      ANALYTICEMPLOYMENTCREATION
# 29              ANALYTICINDEPBOARD
# 30       ANALYTICNOMINATIONCOMMIND
# 31  ANALYTICNONAUDITAUDITFEESRATIO
# 32            ANALYTICNONEXECBOARD
# 33      ANNUAL_MEDIAN_COMPENSATION
# 34         AUDITCOMMNONEXECMEMBERS
# 35                AVGTRAININGHOURS
# 36       BOARDMEETINGATTENDANCEAVG
# 37         CEO_ANNUAL_COMPENSATION
# 38            CEO_PAY_RATIO_MEDIAN
# 39       COMMMEETINGSATTENDANCEAVG
# 40          COMPCOMMNONEXECMEMBERS
# 41          ANALYTICTOTALDONATIONS
# 42              EMPLOYEEFATALITIES
# 43       GENDER_PAY_GAP_PERCENTAGE
# 44      HUMAN_RIGHTS_VIOLATION_PAI
# 45                 LOSTWORKINGDAYS
# 46                        TIRTOTAL
# 47                   TRADEUNIONREP
# 48               TURNOVEREMPLOYEES
# 49                  WOMENEMPLOYEES
# 50                   WOMENMANAGERS
#
#                                    metric_name_update  \
# 0                           Direct air pollution cost
# 1                         Indirect air pollution cost
# 2                         Recycled and reused waste %
# 3                        Direct CO2 emissions scope 1
# 4                      Indirect CO2 emissions scope 2
# 5                      Indirect CO2 emissions scope 3
# 6                       Estimated total CO2 emissions
# 7                               Purchased electricity
# 8                               EMS certified sites %
# 9                             Direct energy purchased
# 10                                  Total energy used
# 11                              Total hazardous waste
# 12                   Direct natural resource use cost
# 13                                      NOx emissions
# 14                       Particulate matter emissions
# 15                          Renewable energy consumed
# 16                          Renewable energy produced
# 17                         Renewable energy purchased
# 18                                      SOx emissions
# 19                             Renewable energy use %
# 20                                      VOC emissions
# 21                               Total waste produced
# 22                               Total waste recycled
# 23                             Total water withdrawal
# 24            Average water consumed per million euro
# 25                     Audit committee independence %
# 26                      Board female representation %
# 27              Compensation committee independence %
# 28                                Employment growth %
# 29                         Independent board member %
# 30               Nomination committee non-executive %
# 31        Non audit to non audit and audit fees ratio
# 32                      Non executive board members %
# 33  Median annual compensation (exclude highest pa...
# 34                    Audit committee non executive %
# 35                Average training hours per employee
# 36                 Average board meeting attendance %
# 37                      CEO total annual compensation
# 38               CEO compensation to median pay ratio
# 39       Average board committee meeting attendance %
# 40             Compensation committee non executive %
# 41             USD donated per million of revenue USD
# 42                          Employee fatalities count
# 43                                   Gender pay gap %
# 44                Severe human right violations count
# 45                            Total lost working days
# 46              Injuries per one million hours worked
# 47                             Trade union coverage %
# 48                                Employee turnover %
# 49                                  Women employees %
# 50                                   Women managers %
#
#                                    metric_description  \
# 0   External cost of pollutants released to air by...
# 1   External cost of indirect emissions of polluta...
# 2   Total recycled and reused waste produced in to...
# 3   Scope 1 emissions that occur within a company’...
# 4   Scope 2 emissions that result from the generat...
# 5   Scope 3 emissions that occur in the value chai...
# 6   The estimated total CO2 emission in tons (with...
# 7                Electricity purchased in gigajoules.
# 8   The percentage of company sites or subsidiarie...
# 9              Direct energy purchased in gigajoules.
# 10  Total energy consumed by a company within its ...
# 11  Total amount of hazardous waste produced in tons.
# 12  External cost of the direct extraction of mine...
# 13     Total amount of NOx emissions emitted in tons.
# 14  Amount of particulate matter (a complex mixtur...
# 15     Total renewable energy consumed in Gigajoules.
# 16  Total renewable energy produced for self-consu...
# 17  Total renewable energy purchased for self-cons...
# 18     Total amount of SOx emissions emitted in tons.
# 19  Total energy consumed from primary renewable e...
# 20  Amount of Volatile Organic Compounds (VOC) emi...
# 21            Total amount of waste produced in tons.
# 22  Total waste that is generated by the company a...
# 23            Total water withdrawal in cubic meters.
# 24  Average amount of water consumed and reclaimed...
# 25  Percentage of independent board members on the...
# 26                Percentage of females on the board.
# 27  Percentage of independent board members on the...
# 28              Employment growth over the last year.
# 29  Percentage of independent board members as rep...
# 30  Percentage of non-executive board members on t...
# 31  All non-audit fees divided by the audit and au...
# 32         Percentage of non-executive board members.
# 33  Median annual compensation for the entire comp...
# 34  Percentage of non-executive board members on t...
# 35   Average hours of training per year per employee.
# 36  The average overall attendance percentage of b...
# 37  Total annual compensation for the highest paid...
# 38  Already reported ratio of CEO compensation ove...
# 39  The average overall attendance percentage of b...
# 40  Percentage of non-executive board members on t...
# 41  Total amount of all donations divided by net s...
# 42  Number of employee fatalities resulting from o...
# 43        Percentage of remuneration of women to men.
# 44  Number of identified cases of severe human rig...
# 45  Total working days lost by the workforce (empl...
# 46  Rate of total number of injuries (Total Injury...
# 47  Percentage of employees represented by indepen...
# 48                   Percentage of employee turnover.
# 49                     Percentage of women employees.
# 50                      Percentage of women managers.
#
#                                           metric_unit data_type pillar
# 0                                           USD (000)     float      E
# 1                                           USD (000)     float      E
# 2                                                   %     float      E
# 3                                           Tons CO2e     float      E
# 4                                           Tons CO2e     float      E
# 5                                           Tons CO2e     float      E
# 6                                            Tons CO2     float      E
# 7                                                  GJ     float      E
# 8                                                   %     float      E
# 9                                                  GJ     float      E
# 10                                                 GJ     float      E
# 11                                               Tons     float      E
# 12                                          USD (000)     float      E
# 13                                        Tons of NOx     float      E
# 14                                               Tons     float      E
# 15                                                 GJ     float      E
# 16                                                 GJ     float      E
# 17                                                 GJ     float      E
# 18                                        Tons of SOx     float      E
# 19                                                  %     float      E
# 20                                        Tons of VOC     float      E
# 21                                               Tons     float      E
# 22                                               Tons     float      E
# 23                                       Cubic meters     float      E
# 24  Cubic meters / million EUR of revenue of inves...     float      E
# 25                                                  %     float      G
# 26                                                  %     float      G
# 27                                                  %     float      G
# 28     % growth in number of employees over last year     float      G
# 29                                                  %     float      G
# 30                                                  %     float      G
# 31                        Non / audit USD / audit USD     float      G
# 32                                                  %     float      G
# 33                                                USD     float      G
# 34                                                  %     float      G
# 35                                     Hours/employee     float      G
# 36                                                  %     float      G
# 37                                                USD     float      G
# 38                                              Ratio     float      G
# 39                                                  %     float      G
# 40                                                  %     float      G
# 41             USD donated per million of revenue USD     float      S
# 42                               Number of fatalities     float      S
# 43                                                  %     float      S
# 44                                 Number of breaches       int      S
# 45                                     Number of days     float      S
# 46                            Injured / million hours     float      S
# 47                                                  %     float      S
# 48                                                  %     float      S
# 49                                                  %     float      S
# 50                                                  %     float      S

# %% [markdown]
# ## Semiconductor Industry for pca model (both numerical and categorical metrics present in csv, may handle it in pca model)

# %%
semiconductor_industry = df[df['industry_name'] == 'Semiconductors']
semiconductor_industry
# Out:
#                                company_name     perm_id data_type  disclosure  \
# 8637     Naseej for Technology Company SJSC  4296741969       int    REPORTED
# 8638     Naseej for Technology Company SJSC  4296741969       int  CALCULATED
# 8639     Naseej for Technology Company SJSC  4296741969       int  CALCULATED
# 8640     Naseej for Technology Company SJSC  4296741969     float   ESTIMATED
# 8641     Naseej for Technology Company SJSC  4296741969       int  CALCULATED
# ...                                     ...         ...       ...         ...
# 6778830          Seoul Semiconductor Co Ltd  4295882677     float   ESTIMATED
# 6778835          Seoul Semiconductor Co Ltd  4295882677       int  CALCULATED
# 6778849          Seoul Semiconductor Co Ltd  4295882677       int  CALCULATED
# 6778854          Seoul Semiconductor Co Ltd  4295882677     float   ESTIMATED
# 6778859                   East Group Co Ltd  5000507925     float   ESTIMATED
#
#                                         metric_description  \
# 8637     Does the company describe, claim to have or me...
# 8638     Does the company have a policy to avoid the us...
# 8639     Is the senior executive's compensation linked ...
# 8640     Average amount of water consumed and reclaimed...
# 8641     Are all shares of the company providing equal ...
# ...                                                    ...
# 6778830  Scope 2 emissions that result from the generat...
# 6778835  Has the company established a program or an in...
# 6778849  Does the company report on making proactive en...
# 6778854  Amount of Volatile Organic Compounds (VOC) emi...
# 6778859     Total amount of NOx emissions emitted in tons.
#
#                           metric_name  \
# 8637     POLICY_FREEDOMOF_ASSOCIATION
# 8638              POLICY_FORCED_LABOR
# 8639      ANALYTICCSR_COMP_INCENTIVES
# 8640                WATER_USE_PAI_M10
# 8641           ANALYTIC_VOTING_RIGHTS
# ...                               ...
# 6778830             CO2INDIRECTSCOPE2
# 6778835      ANIMAL_TESTING_REDUCTION
# 6778849               ENV_INVESTMENTS
# 6778854                  VOCEMISSIONS
# 6778859                  NOXEMISSIONS
#
#                                                metric_unit  metric_value  \
# 8637                                                Yes/No          0.00
# 8638                                                Yes/No          0.00
# 8639                                                Yes/No          0.00
# 8640     Cubic meters / million EUR of revenue of inves...          0.00
# 8641                                                Yes/No          0.00
# ...                                                    ...           ...
# 6778830                                          Tons CO2e      41959.73
# 6778835                                             Yes/No          0.00
# 6778849                                             Yes/No          0.00
# 6778854                                        Tons of VOC         25.78
# 6778859                                        Tons of NOx          2.20
#
#         metric_year  nb_points_of_observations  metric_period provider_name  \
# 8637     2021-12-31                        274            NaN    Clarity AI
# 8638     2020-12-31                        274            NaN    Clarity AI
# 8639     2019-12-31                        274            NaN    Clarity AI
# 8640     2024-12-31                        274            NaN    Clarity AI
# 8641     2020-12-31                        274            NaN    Clarity AI
# ...             ...                        ...            ...           ...
# 6778830  2022-12-31                        166            NaN    Clarity AI
# 6778835  2019-12-31                        166            NaN    Clarity AI
# 6778849  2019-12-31                        166            NaN    Clarity AI
# 6778854  2019-12-31                        166            NaN    Clarity AI
# 6778859  2020-12-31                        166            NaN    Clarity AI
#
#                reported_date pillar headquarter_country   industry_name
# 8637     2021-12-31 00:00:00      S                 NaN  Semiconductors
# 8638     2020-12-31 00:00:00      S                 NaN  Semiconductors
# 8639     2019-12-31 00:00:00      G                 NaN  Semiconductors
# 8640     2024-12-20 00:00:00      E                 NaN  Semiconductors
# 8641     2020-12-31 00:00:00      G                 NaN  Semiconductors
# ...                      ...    ...                 ...             ...
# 6778830                  NaN      E         Korea, Rep.  Semiconductors
# 6778835  2019-12-31 00:00:00      S         Korea, Rep.  Semiconductors
# 6778849  2019-12-31 00:00:00      E         Korea, Rep.  Semiconductors
# 6778854                  NaN      E         Korea, Rep.  Semiconductors
# 6778859                  NaN      E               China  Semiconductors
#
# [105528 rows x 16 columns]

# %%
companies_in_semiconductors = semiconductor_industry['perm_id'].nunique()
companies_in_semiconductors
# Out:
# 859

# %%
# sort by perm_id, then year
pivot_df = semiconductor_industry.pivot(index=['perm_id', 'metric_year'], columns='metric_name', values='metric_value')
pivot_df
# Out:
# metric_name             AIRPOLLUTANTS_DIRECT  AIRPOLLUTANTS_INDIRECT  \
# perm_id    metric_year
# 4295857321 2016-12-31                    NaN                     NaN
#            2017-12-31                    NaN                     NaN
#            2018-12-31                    NaN                 5423.10
#            2019-12-31                    NaN                 2044.09
#            2020-12-31                    NaN                 2140.60
# ...                                      ...                     ...
# 5083349161 2023-12-31                    NaN                     NaN
# 5084952432 2019-12-31                    NaN                     NaN
#            2020-12-31                    NaN                     NaN
#            2021-12-31                    NaN                     NaN
#            2022-12-31                    NaN                     NaN
#
# metric_name             ANALYTICAUDITCOMMIND  ANALYTICBOARDFEMALE  \
# perm_id    metric_year
# 4295857321 2016-12-31                    NaN                  NaN
#            2017-12-31                    NaN                  NaN
#            2018-12-31                    NaN                  NaN
#            2019-12-31                    NaN                  NaN
#            2020-12-31                    NaN                  NaN
# ...                                      ...                  ...
# 5083349161 2023-12-31                    NaN                  NaN
# 5084952432 2019-12-31                    NaN                  NaN
#            2020-12-31                    NaN                  NaN
#            2021-12-31                    NaN                  NaN
#            2022-12-31                    NaN                  NaN
#
# metric_name             ANALYTICCEO_CHAIRMAN_SEPARATION  ANALYTICCOMPCOMMIND  \
# perm_id    metric_year
# 4295857321 2016-12-31                               NaN                  NaN
#            2017-12-31                               NaN                  NaN
#            2018-12-31                               NaN                  NaN
#            2019-12-31                               NaN                  NaN
#            2020-12-31                               NaN                  NaN
# ...                                                 ...                  ...
# 5083349161 2023-12-31                               NaN                  NaN
# 5084952432 2019-12-31                               NaN                  NaN
#            2020-12-31                               NaN                  NaN
#            2021-12-31                               NaN                  NaN
#            2022-12-31                               NaN                  NaN
#
# metric_name             ANALYTICCSR_COMP_INCENTIVES  \
# perm_id    metric_year
# 4295857321 2016-12-31                           NaN
#            2017-12-31                           NaN
#            2018-12-31                           NaN
#            2019-12-31                           0.0
#            2020-12-31                           0.0
# ...                                             ...
# 5083349161 2023-12-31                           NaN
# 5084952432 2019-12-31                           NaN
#            2020-12-31                           NaN
#            2021-12-31                           NaN
#            2022-12-31                           NaN
#
# metric_name             ANALYTICEMPLOYMENTCREATION  ANALYTICINDEPBOARD  \
# perm_id    metric_year
# 4295857321 2016-12-31                         5.56                 NaN
#            2017-12-31                         5.26                 NaN
#            2018-12-31                         0.00                 NaN
#            2019-12-31                        25.00                 NaN
#            2020-12-31                          NaN                 NaN
# ...                                            ...                 ...
# 5083349161 2023-12-31                        61.86                 NaN
# 5084952432 2019-12-31                          NaN                 NaN
#            2020-12-31                        20.00                 NaN
#            2021-12-31                        13.89                 NaN
#            2022-12-31                        -2.44                 NaN
#
# metric_name             ANALYTICNOMINATIONCOMMIND  ...  \
# perm_id    metric_year                             ...
# 4295857321 2016-12-31                         NaN  ...
#            2017-12-31                         NaN  ...
#            2018-12-31                         NaN  ...
#            2019-12-31                         NaN  ...
#            2020-12-31                         NaN  ...
# ...                                           ...  ...
# 5083349161 2023-12-31                         NaN  ...
# 5084952432 2019-12-31                         NaN  ...
#            2020-12-31                         NaN  ...
#            2021-12-31                         NaN  ...
#            2022-12-31                         NaN  ...
#
# metric_name             VOC_EMISSIONS_REDUCTION  WASTETOTAL  WASTE_RECYCLED  \
# perm_id    metric_year
# 4295857321 2016-12-31                       NaN        8.43             NaN
#            2017-12-31                       NaN       12.00             NaN
#            2018-12-31                       NaN        9.17             NaN
#            2019-12-31                       NaN        8.67             NaN
#            2020-12-31                       NaN        3.03             NaN
# ...                                         ...         ...             ...
# 5083349161 2023-12-31                       NaN         NaN             NaN
# 5084952432 2019-12-31                       NaN         NaN             NaN
#            2020-12-31                       NaN         NaN             NaN
#            2021-12-31                       NaN         NaN             NaN
#            2022-12-31                       NaN         NaN             NaN
#
# metric_name             WASTE_REDUCTION_TOTAL  WATERWITHDRAWALTOTAL  \
# perm_id    metric_year
# 4295857321 2016-12-31                     NaN                822.87
#            2017-12-31                     NaN               1817.88
#            2018-12-31                     NaN               1959.45
#            2019-12-31                     NaN               2024.83
#            2020-12-31                     NaN               1984.61
# ...                                       ...                   ...
# 5083349161 2023-12-31                     NaN              35039.05
# 5084952432 2019-12-31                     NaN               8468.87
#            2020-12-31                     NaN              10501.31
#            2021-12-31                     NaN              11205.37
#            2022-12-31                     NaN              11889.50
#
# metric_name             WATER_TECHNOLOGIES  WATER_USE_PAI_M10  \
# perm_id    metric_year
# 4295857321 2016-12-31                  NaN                NaN
#            2017-12-31                  NaN                NaN
#            2018-12-31                  NaN                NaN
#            2019-12-31                  NaN                NaN
#            2020-12-31                  NaN                NaN
# ...                                    ...                ...
# 5083349161 2023-12-31                  NaN                NaN
# 5084952432 2019-12-31                  NaN                NaN
#            2020-12-31                  NaN                NaN
#            2021-12-31                  NaN                NaN
#            2022-12-31                  NaN                NaN
#
# metric_name             WHISTLEBLOWER_PROTECTION  WOMENEMPLOYEES  \
# perm_id    metric_year
# 4295857321 2016-12-31                        NaN             NaN
#            2017-12-31                        NaN             NaN
#            2018-12-31                        NaN             NaN
#            2019-12-31                        NaN             NaN
#            2020-12-31                        NaN             NaN
# ...                                          ...             ...
# 5083349161 2023-12-31                        NaN             NaN
# 5084952432 2019-12-31                        NaN             NaN
#            2020-12-31                        NaN             NaN
#            2021-12-31                        NaN             NaN
#            2022-12-31                        NaN             NaN
#
# metric_name             WOMENMANAGERS
# perm_id    metric_year
# 4295857321 2016-12-31             NaN
#            2017-12-31             NaN
#            2018-12-31             NaN
#            2019-12-31             NaN
#            2020-12-31             NaN
# ...                               ...
# 5083349161 2023-12-31             NaN
# 5084952432 2019-12-31             NaN
#            2020-12-31             NaN
#            2021-12-31             NaN
#            2022-12-31             NaN
#
# [7001 rows x 102 columns]

# %%
pivot_df.to_csv('semiconductor.csv')

# %%
# by year first, then by perm_id
pivot_df1 = semiconductor_industry.pivot(index=['metric_year', 'perm_id'], columns='metric_name', values='metric_value')
pivot_df1
# Out:
# metric_name             AIRPOLLUTANTS_DIRECT  AIRPOLLUTANTS_INDIRECT  \
# metric_year perm_id
# 2016-12-31  4295857321                   NaN                     NaN
#             4295857863                   NaN                     NaN
#             4295858147                  5.31                     NaN
#             4295859475                 17.33                     NaN
#             4295859530                   NaN                     NaN
# ...                                      ...                     ...
# 2024-12-31  5080529117                   NaN                     NaN
#             5081079864                   NaN                     NaN
#             5081654561                   NaN                     NaN
#             5082156409                   NaN                     NaN
#             5082432234                   NaN                     NaN
#
# metric_name             ANALYTICAUDITCOMMIND  ANALYTICBOARDFEMALE  \
# metric_year perm_id
# 2016-12-31  4295857321                   NaN                  NaN
#             4295857863                   NaN                  NaN
#             4295858147                   NaN                  NaN
#             4295859475                   NaN                  NaN
#             4295859530                   NaN                  NaN
# ...                                      ...                  ...
# 2024-12-31  5080529117                   NaN                  NaN
#             5081079864                   NaN                  NaN
#             5081654561                   NaN                  NaN
#             5082156409                   NaN                  NaN
#             5082432234                   NaN                  NaN
#
# metric_name             ANALYTICCEO_CHAIRMAN_SEPARATION  ANALYTICCOMPCOMMIND  \
# metric_year perm_id
# 2016-12-31  4295857321                              NaN                  NaN
#             4295857863                              NaN                  NaN
#             4295858147                              NaN                  NaN
#             4295859475                              NaN                  NaN
#             4295859530                              NaN                  NaN
# ...                                                 ...                  ...
# 2024-12-31  5080529117                              NaN                  NaN
#             5081079864                              NaN                  NaN
#             5081654561                              NaN                  NaN
#             5082156409                              NaN                  NaN
#             5082432234                              NaN                  NaN
#
# metric_name             ANALYTICCSR_COMP_INCENTIVES  \
# metric_year perm_id
# 2016-12-31  4295857321                          NaN
#             4295857863                          NaN
#             4295858147                          NaN
#             4295859475                          NaN
#             4295859530                          NaN
# ...                                             ...
# 2024-12-31  5080529117                          NaN
#             5081079864                          NaN
#             5081654561                          NaN
#             5082156409                          NaN
#             5082432234                          NaN
#
# metric_name             ANALYTICEMPLOYMENTCREATION  ANALYTICINDEPBOARD  \
# metric_year perm_id
# 2016-12-31  4295857321                        5.56                 NaN
#             4295857863                         NaN                 NaN
#             4295858147                         NaN                 NaN
#             4295859475                        4.36                 NaN
#             4295859530                       24.32                 NaN
# ...                                            ...                 ...
# 2024-12-31  5080529117                         NaN                 NaN
#             5081079864                         NaN                 NaN
#             5081654561                       32.89                 NaN
#             5082156409                         NaN                 NaN
#             5082432234                         NaN                 NaN
#
# metric_name             ANALYTICNOMINATIONCOMMIND  ...  \
# metric_year perm_id                                ...
# 2016-12-31  4295857321                        NaN  ...
#             4295857863                        NaN  ...
#             4295858147                        NaN  ...
#             4295859475                        NaN  ...
#             4295859530                        NaN  ...
# ...                                           ...  ...
# 2024-12-31  5080529117                        NaN  ...
#             5081079864                        NaN  ...
#             5081654561                        NaN  ...
#             5082156409                        NaN  ...
#             5082432234                        NaN  ...
#
# metric_name             VOC_EMISSIONS_REDUCTION  WASTETOTAL  WASTE_RECYCLED  \
# metric_year perm_id
# 2016-12-31  4295857321                      NaN        8.43             NaN
#             4295857863                      NaN      192.58             NaN
#             4295858147                      NaN         NaN             NaN
#             4295859475                      NaN     1456.08             NaN
#             4295859530                      NaN         NaN             NaN
# ...                                         ...         ...             ...
# 2024-12-31  5080529117                      NaN         NaN             NaN
#             5081079864                      NaN         NaN             NaN
#             5081654561                      NaN         NaN             NaN
#             5082156409                      NaN         NaN             NaN
#             5082432234                      NaN         NaN             NaN
#
# metric_name             WASTE_REDUCTION_TOTAL  WATERWITHDRAWALTOTAL  \
# metric_year perm_id
# 2016-12-31  4295857321                    NaN                822.87
#             4295857863                    NaN               2600.78
#             4295858147                    NaN               2266.83
#             4295859475                    NaN             102235.06
#             4295859530                    NaN                445.18
# ...                                       ...                   ...
# 2024-12-31  5080529117                    NaN                   NaN
#             5081079864                    NaN                   NaN
#             5081654561                    NaN                   NaN
#             5082156409                    NaN                   NaN
#             5082432234                    NaN                   NaN
#
# metric_name             WATER_TECHNOLOGIES  WATER_USE_PAI_M10  \
# metric_year perm_id
# 2016-12-31  4295857321                 NaN                NaN
#             4295857863                 NaN                NaN
#             4295858147                 NaN                NaN
#             4295859475                 NaN                NaN
#             4295859530                 NaN                NaN
# ...                                    ...                ...
# 2024-12-31  5080529117                 NaN                0.0
#             5081079864                 NaN                0.0
#             5081654561                 NaN                NaN
#             5082156409                 NaN                0.0
#             5082432234                 NaN                0.0
#
# metric_name             WHISTLEBLOWER_PROTECTION  WOMENEMPLOYEES  \
# metric_year perm_id
# 2016-12-31  4295857321                       NaN             NaN
#             4295857863                       NaN             NaN
#             4295858147                       NaN             NaN
#             4295859475                       NaN             NaN
#             4295859530                       NaN             NaN
# ...                                          ...             ...
# 2024-12-31  5080529117                       NaN             NaN
#             5081079864                       NaN             NaN
#             5081654561                       NaN             NaN
#             5082156409                       NaN             NaN
#             5082432234                       NaN             NaN
#
# metric_name             WOMENMANAGERS
# metric_year perm_id
# 2016-12-31  4295857321            NaN
#             4295857863            NaN
#             4295858147            NaN
#             4295859475            NaN
#             4295859530            NaN
# ...                               ...
# 2024-12-31  5080529117            NaN
#             5081079864            NaN
#             5081654561            NaN
#             5082156409            NaN
#             5082432234            NaN
#
# [7001 rows x 102 columns]

# %%
pivot_df1.to_csv('semiconductor_by_year.csv')

# %%
set(df['metric_name'].unique().tolist()) - set(pivot_df.columns.tolist())
# Out:
# {'CO2_NO_EQUIVALENTS', 'ENERGYPURCHASEDDIRECT'}

# %%
#missing two metrics in semiconductors industry
semiconductor_industry[semiconductor_industry['metric_name'] == 'ENERGYPURCHASEDDIRECT']
semiconductor_industry[semiconductor_industry['metric_name'] == 'CO2_NO_EQUIVALENTS']
# Out:
# Empty DataFrame
# Columns: [company_name, perm_id, data_type, disclosure, metric_description, metric_name, metric_unit, metric_value, metric_year, nb_points_of_observations, metric_period, provider_name, reported_date, pillar, headquarter_country, industry_name]
# Index: []
# Empty DataFrame
# Columns: [company_name, perm_id, data_type, disclosure, metric_description, metric_name, metric_unit, metric_value, metric_year, nb_points_of_observations, metric_period, provider_name, reported_date, pillar, headquarter_country, industry_name]
# Index: []

# %% [markdown]
# ## Semiconductor Industry map metrics under categories IFRS S2 for sasb
# ### This part will export a csv and we match metrics to categories manually in csv

# %%
semiconductor_industry = df[df['industry_name'] == 'Semiconductors']

# %%
semiconductor_numerical_metrics = semiconductor_industry[semiconductor_industry['metric_unit'] != 'Yes/No']

# %%
semiconductor_numerical_metrics_unique = semiconductor_numerical_metrics[['metric_name', 'metric_description', 'metric_unit', 'data_type', 'pillar']].drop_duplicates()

# %%
semiconductor_numerical_metrics_df = semiconductor_numerical_metrics_unique.merge(
    updated_metric_info[['metric_name', 'metric_name_update']],
    on='metric_name',
    how='left'
)
semiconductor_numerical_metrics_df['category'] = ''

# %%
semiconductor_numerical_metrics_df.sort_values(by=['pillar', 'metric_name']).to_csv('semiconductor_metric_info.csv', index=False)

# %% [markdown]
# ## Biotechnology & Pharmaceuticals for pca

# %%
bp_industry = df[df['industry_name'] == 'Biotechnology & Pharmaceuticals']
bp_industry
# Out:
#                         company_name     perm_id data_type  disclosure  \
# 21820    Rohto Pharmaceutical Co Ltd  4295877894     float   ESTIMATED
# 21821    Rohto Pharmaceutical Co Ltd  4295877894       int    REPORTED
# 21825    Rohto Pharmaceutical Co Ltd  4295877894     float   ESTIMATED
# 21831    Rohto Pharmaceutical Co Ltd  4295877894     float   ESTIMATED
# 21844    Rohto Pharmaceutical Co Ltd  4295877894       int  CALCULATED
# ...                              ...         ...       ...         ...
# 6790787     Flexion Therapeutics Inc  4297906483       int    REPORTED
# 6790788     Flexion Therapeutics Inc  4297906483     float   ESTIMATED
# 6790789     Flexion Therapeutics Inc  4297906483     float   ESTIMATED
# 6790790     Flexion Therapeutics Inc  4297906483       int  CALCULATED
# 6790791     Flexion Therapeutics Inc  4297906483       int  CALCULATED
#
#                                         metric_description  \
# 21820              Total amount of waste produced in tons.
# 21821    Does the company have a policy to improve emis...
# 21825    Total energy consumed by a company within its ...
# 21831       Total amount of NOx emissions emitted in tons.
# 21844    Does the company report on its impact on biodi...
# ...                                                    ...
# 6790787  Does the company report on initiatives to redu...
# 6790788  Amount of Volatile Organic Compounds (VOC) emi...
# 6790789  Scope 1 emissions that occur within a company’...
# 6790790  Does the company report or show to use human r...
# 6790791  Is the senior executive's compensation linked ...
#
#                            metric_name  metric_unit  metric_value metric_year  \
# 21820                       WASTETOTAL         Tons       8249.13  2018-12-31
# 21821                 POLICY_EMISSIONS       Yes/No          1.00  2024-12-31
# 21825                   ENERGYUSETOTAL           GJ     185727.92  2016-12-31
# 21831                     NOXEMISSIONS  Tons of NOx         15.48  2018-12-31
# 21844    BIODIVERSITY_IMPACT_REDUCTION       Yes/No          0.00  2019-12-31
# ...                                ...          ...           ...         ...
# 6790787   N_OXS_OX_EMISSIONS_REDUCTION       Yes/No          0.00  2020-12-31
# 6790788                   VOCEMISSIONS  Tons of VOC          2.03  2020-12-31
# 6790789                CO2DIRECTSCOPE1    Tons CO2e          9.52  2017-12-31
# 6790790        HUMAN_RIGHTS_CONTRACTOR       Yes/No          0.00  2019-12-31
# 6790791    ANALYTICCSR_COMP_INCENTIVES       Yes/No          0.00  2019-12-31
#
#          nb_points_of_observations  metric_period provider_name  \
# 21820                          251            NaN    Clarity AI
# 21821                          251            NaN    Clarity AI
# 21825                          251            NaN    Clarity AI
# 21831                          251            NaN    Clarity AI
# 21844                          251            NaN    Clarity AI
# ...                            ...            ...           ...
# 6790787                        134            NaN    Clarity AI
# 6790788                        134            NaN    Clarity AI
# 6790789                        134            NaN    Clarity AI
# 6790790                        134            NaN    Clarity AI
# 6790791                        134            NaN    Clarity AI
#
#                reported_date pillar headquarter_country  \
# 21820                    NaN      E               Japan
# 21821    2024-12-31 00:00:00      E               Japan
# 21825                    NaN      E               Japan
# 21831                    NaN      E               Japan
# 21844    2019-09-27 14:29:37      E               Japan
# ...                      ...    ...                 ...
# 6790787  2020-12-31 00:00:00      E       United States
# 6790788                  NaN      E       United States
# 6790789                  NaN      E       United States
# 6790790  2019-12-31 00:00:00      S       United States
# 6790791  2019-12-31 00:00:00      G       United States
#
#                            industry_name
# 21820    Biotechnology & Pharmaceuticals
# 21821    Biotechnology & Pharmaceuticals
# 21825    Biotechnology & Pharmaceuticals
# 21831    Biotechnology & Pharmaceuticals
# 21844    Biotechnology & Pharmaceuticals
# ...                                  ...
# 6790787  Biotechnology & Pharmaceuticals
# 6790788  Biotechnology & Pharmaceuticals
# 6790789  Biotechnology & Pharmaceuticals
# 6790790  Biotechnology & Pharmaceuticals
# 6790791  Biotechnology & Pharmaceuticals
#
# [347738 rows x 16 columns]

# %%
companies_in_bp = bp_industry['perm_id'].nunique()
companies_in_bp
# Out:
# 3157

# %%
pivot_df = bp_industry.pivot(index=['perm_id', 'metric_year'], columns='metric_name', values='metric_value')
pivot_df.to_csv('biotech.csv')

# %%
pivot_df1 = bp_industry.pivot(index=['metric_year', 'perm_id'], columns='metric_name', values='metric_value')
pivot_df1.to_csv('biotech_by_year.csv')

# %%
set(df['metric_name'].unique().tolist()) - set(pivot_df.columns.tolist())
# Out:
# {'CO2_NO_EQUIVALENTS', 'ENERGYPURCHASEDDIRECT'}

# %% [markdown]
# ## Biotechnology & Pharmaceuticals Industry map metrics under categories IFRS S2
# ### This part will export a csv and we match metrics to categories manually in csv

# %%
bio_pharm_industry = df[df['industry_name'] == 'Biotechnology & Pharmaceuticals']
bio_pharm_numerical_metrics = bio_pharm_industry[bio_pharm_industry['metric_unit'] != 'Yes/No']
bio_pharm_numerical_metrics_unique = bio_pharm_numerical_metrics[['metric_name', 'metric_description', 'metric_unit', 'data_type', 'pillar']].drop_duplicates()
bio_pharm_numerical_metrics_df = bio_pharm_numerical_metrics_unique.merge(
    updated_metric_info[['metric_name', 'metric_name_update']],
    on='metric_name',
    how='left'
)
bio_pharm_numerical_metrics_df['category'] = ''
bio_pharm_numerical_metrics_df.sort_values(by=['pillar', 'metric_name']).to_csv('bio_pharm_metric_info.csv', index=False)

# %% [markdown]
# ## Software & IT services Industry map metrics under categories IFRS S2
# ### This part will export a csv and we match metrics to categories manually in csv

# %%
software_it_industry = df[df['industry_name'] == 'Software & IT Services']
software_it_numerical_metrics = software_it_industry[software_it_industry['metric_unit'] != 'Yes/No']
software_it_numerical_metrics_unique = software_it_numerical_metrics[['metric_name', 'metric_description', 'metric_unit', 'data_type', 'pillar']].drop_duplicates()
software_it_numerical_metrics_df = software_it_numerical_metrics_unique.merge(
    updated_metric_info[['metric_name', 'metric_name_update']],
    on='metric_name',
    how='left'
)
software_it_numerical_metrics_df['category'] = ''
software_it_numerical_metrics_df.sort_values(by=['pillar', 'metric_name']).to_csv('software_it_metric_info.csv', index=False)

# %% [markdown]
# ## Industrial Machinery & Goods	 Industry map metrics under categories IFRS S2
# ### This part will export a csv and we match metrics to categories manually in csv

# %%
machinery_goods_industry = df[df['industry_name'] == 'Industrial Machinery & Goods']
machinery_goods_numerical_metrics = machinery_goods_industry[machinery_goods_industry['metric_unit'] != 'Yes/No']
machinery_goods_numerical_metrics_unique = machinery_goods_numerical_metrics[['metric_name', 'metric_description', 'metric_unit', 'data_type', 'pillar']].drop_duplicates()
machinery_goods_numerical_metrics_df = machinery_goods_numerical_metrics_unique.merge(
    updated_metric_info[['metric_name', 'metric_name_update']],
    on='metric_name',
    how='left'
)
machinery_goods_numerical_metrics_df['category'] = ''
machinery_goods_numerical_metrics_df.sort_values(by=['pillar', 'metric_name']).to_csv('machinery_goods_metric_info.csv', index=False)

# %% [markdown]
# ## This part will export a csv for all industry and an excel checklist, only the final result will be store in github

# %%
df['industry_name'].drop_duplicates().sort_values().to_excel('industry_mapping_checklist.xlsx', index=False)

# %%
industry_list = df['industry_name'].drop_duplicates().tolist()
for industry in industry_list:
    industry_df = df[df['industry_name'] == industry]
    numerical_metrics = industry_df[industry_df['metric_unit'] != 'Yes/No']
    numerical_metrics_unique = numerical_metrics[['metric_name', 'metric_description', 'metric_unit', 'data_type', 'pillar']].drop_duplicates()
    numerical_metrics_df = numerical_metrics_unique.merge(
        updated_metric_info[['metric_name', 'metric_name_update']],
        on='metric_name',
        how='left'
    )
    numerical_metrics_df['category'] = ''
    numerical_metrics_df.sort_values(by=['pillar', 'metric_name']).to_csv(f'industry_before/{industry}_metric_info.csv', index=False)

# %% [markdown]
# ### This part will combine all done mapped industry csv to single csv

# %%
#SASB mapping table to csv

mapped_files = os.listdir("../ingestion_service/data/industry_with_categories/")
mapped_csv_files = [f for f in mapped_files if re.search(r'.*info\.csv$', f)]
dfs = []
for csv in mapped_csv_files:
    industry_name = csv[:-16]
    df_chunk = pd.read_csv(f"../ingestion_service/data/industry_with_categories/{csv}", sep=',')
    df_chunk = df_chunk.dropna(subset=['category'])
    df_chunk['industry_name'] = industry_name
    dfs.append(df_chunk)

df = pd.concat(dfs, ignore_index=True)
df
# Out:
#                     metric_name  \
# 0               CO2DIRECTSCOPE1
# 1             CO2INDIRECTSCOPE2
# 2             CO2INDIRECTSCOPE3
# 3   ANALYTICWASTERECYCLINGRATIO
# 4                ENERGYUSETOTAL
# ..                          ...
# 83               ENERGYUSETOTAL
# 84               HAZARDOUSWASTE
# 85     TRANALYTICRENEWENERGYUSE
# 86         WATERWITHDRAWALTOTAL
# 87            WATER_USE_PAI_M10
#
#                                    metric_description  \
# 0   Scope 1 emissions that occur within a company’...
# 1   Scope 2 emissions that result from the generat...
# 2   Scope 3 emissions that occur in the value chai...
# 3   Total recycled and reused waste produced in to...
# 4   Total energy consumed by a company within its ...
# ..                                                ...
# 83  Total energy consumed by a company within its ...
# 84  Total amount of hazardous waste produced in tons.
# 85  Total energy consumed from primary renewable e...
# 86            Total water withdrawal in cubic meters.
# 87  Average amount of water consumed and reclaimed...
#
#                                           metric_unit data_type pillar  \
# 0                                           Tons CO2e     float      E
# 1                                           Tons CO2e     float      E
# 2                                           Tons CO2e     float      E
# 3                                                   %     float      E
# 4                                                  GJ     float      E
# ..                                                ...       ...    ...
# 83                                                 GJ     float      E
# 84                                               Tons     float      E
# 85                                                  %     float      E
# 86                                       Cubic meters     float      E
# 87  Cubic meters / million EUR of revenue of inves...     float      E
#
#                          metric_name_update  \
# 0              Direct CO2 emissions scope 1
# 1            Indirect CO2 emissions scope 2
# 2            Indirect CO2 emissions scope 3
# 3               Recycled and reused waste %
# 4                         Total energy used
# ..                                      ...
# 83                        Total energy used
# 84                    Total hazardous waste
# 85                   Renewable energy use %
# 86                   Total water withdrawal
# 87  Average water consumed per million euro
#
#                                   category     industry_name
# 0    Product Design & Lifecycle Management  Commercial Banks
# 1    Product Design & Lifecycle Management  Commercial Banks
# 2    Product Design & Lifecycle Management  Commercial Banks
# 3   Waste & Hazardous Materials Management        Auto Parts
# 4                        Energy Management        Auto Parts
# ..                                     ...               ...
# 83                       Energy Management    Semiconductors
# 84  Waste & Hazardous Materials Management    Semiconductors
# 85                       Energy Management    Semiconductors
# 86           Water & Wastewater Management    Semiconductors
# 87           Water & Wastewater Management    Semiconductors
#
# [88 rows x 8 columns]

# %%
sasb_mapping_df = df[['industry_name', 'category', 'metric_name', 'metric_name_update']]
sasb_mapping_df.rename(columns={
    'industry_name': 'industry_name',
    'category': 'category',
    'metric_name': 'metric_name',
    'metric_name_update': 'updated_metric_name'
}, inplace=True)
sasb_mapping_df
# Out:
# /var/folders/pt/8p9w36290ms15w_t5l6pm9sr0000gn/T/ipykernel_16153/1873071653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sasb_mapping_df.rename(columns={
#        industry_name                                category  \
# 0   Commercial Banks   Product Design & Lifecycle Management
# 1   Commercial Banks   Product Design & Lifecycle Management
# 2   Commercial Banks   Product Design & Lifecycle Management
# 3         Auto Parts  Waste & Hazardous Materials Management
# 4         Auto Parts                       Energy Management
# ..               ...                                     ...
# 83    Semiconductors                       Energy Management
# 84    Semiconductors  Waste & Hazardous Materials Management
# 85    Semiconductors                       Energy Management
# 86    Semiconductors           Water & Wastewater Management
# 87    Semiconductors           Water & Wastewater Management
#
#                     metric_name                      updated_metric_name
# 0               CO2DIRECTSCOPE1             Direct CO2 emissions scope 1
# 1             CO2INDIRECTSCOPE2           Indirect CO2 emissions scope 2
# 2             CO2INDIRECTSCOPE3           Indirect CO2 emissions scope 3
# 3   ANALYTICWASTERECYCLINGRATIO              Recycled and reused waste %
# 4                ENERGYUSETOTAL                        Total energy used
# ..                          ...                                      ...
# 83               ENERGYUSETOTAL                        Total energy used
# 84               HAZARDOUSWASTE                    Total hazardous waste
# 85     TRANALYTICRENEWENERGYUSE                   Renewable energy use %
# 86         WATERWITHDRAWALTOTAL                   Total water withdrawal
# 87            WATER_USE_PAI_M10  Average water consumed per million euro
#
# [88 rows x 4 columns]

# %%
sasb_mapping_df.to_csv("../ingestion_service/data/industry_with_categories/sasb_mapping_table.csv", index=False)
